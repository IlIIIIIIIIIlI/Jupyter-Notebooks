# %% [markdown]
# # Analisando o bônus 2024

# %% [markdown]
# ## Preparando os dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
import scipy.stats as stats
from scipy.stats import zscore
from scipy.spatial.distance import pdist
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
import pingouin as pg
import plotly.express as px 
import plotly.graph_objects as go
import plotly.io as pio

from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
escolas = pd.read_excel('Bônus 2024 - Modificado.xlsx') 

escolas[0:5]
# Out:
#    COD. CIE                               ESCOLA   DIRETORIA   MUNICIPIO  \
# 0     30806                         Helen Keller  Adamantina  Adamantina
# 1     31045                 Durvalino Grion Prof  Adamantina  Adamantina
# 2     31112  Fleurides Cavallini Menechino Profa  Adamantina  Adamantina
# 3     31252        Julieta Guedes Mendonca Profa  Adamantina  Adamantina
# 4     31264                           9 De Julho  Adamantina  Adamantina
#
#    Total     Alunos Particip.  % TPS  TPS Elegível  Meta IFA  % IFA  \
# 0                          95   0.65             0      0.77   0.85
# 1                          74   0.87             1      0.80   0.85
# 2                         128   0.92             1      0.80   0.84
# 3                         164   0.83             1      0.80   0.82
# 4                         217   0.98             1      0.80   0.87
#
#    IFA Elegível  ...  IDESP Ens.\nMédio  Part.  Ens Fund. (A. Iniciais)  \
# 0             1  ...               1.83                               0
# 1             1  ...                NaN                               0
# 2             1  ...               2.70                               0
# 3             1  ...               1.71                               0
# 4             1  ...               4.28                               0
#
#    Part. Ens. Fund. (A. Finais)  Part. Ensino Médio  Total Part. 2023  \
# 0                            47                  48                95
# 1                            74                   0                74
# 2                            83                  45               128
# 3                            87                  77               164
# 4                           129                  88               217
#
#    IDESP 2023  Ouro  Diamante   IC  ICM
# 0        2.21  2.49      2.83  0.0  0.0
# 1        3.20  4.73      4.98  0.0  0.0
# 2        3.26  3.44      3.74  0.0  0.0
# 3        2.08  3.02      3.30  0.0  0.0
# 4        4.26  4.42      4.68  0.0  0.0
#
# [5 rows x 22 columns]

# %%
escolas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5014 entries, 0 to 5013
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   COD. CIE                          5014 non-null   int64
#  1   ESCOLA                            5014 non-null   object
#  2   DIRETORIA                         5014 non-null   object
#  3   MUNICIPIO                         5014 non-null   object
#  4   Total     Alunos Particip.        5014 non-null   int64
#  5   % TPS                             5014 non-null   float64
#  6   TPS Elegível                      5014 non-null   int64
#  7   Meta IFA                          5014 non-null   float64
#  8   % IFA                             5014 non-null   float64
#  9   IFA Elegível                      5014 non-null   int64
#  10  IDESP
# Ens. Fund. (anos iniciais)  1345 non-null   float64
#  11  IDESP  Ens.
# Fund. (anos finais)   3663 non-null   float64
#  12  IDESP Ens.
# Médio                  3590 non-null   float64
#  13  Part.  Ens Fund. (A. Iniciais)    5014 non-null   int64
#  14  Part. Ens. Fund. (A. Finais)      5014 non-null   int64
#  15  Part. Ensino Médio                5014 non-null   int64
#  16  Total Part. 2023                  5014 non-null   int64
#  17  IDESP 2023                        5014 non-null   float64
#  18  Ouro                              5014 non-null   float64
#  19  Diamante                          5014 non-null   float64
#  20  IC                                5014 non-null   float64
#  21  ICM                               5014 non-null   float64
# dtypes: float64(11), int64(8), object(3)
# memory usage: 861.9+ KB

# %% [markdown]
# ## Analisando as escolas que receberam o Bônus 2024

# %%
escolas_diamante = escolas[escolas['IDESP 2023'] > escolas['Diamante']].sort_values(by='IDESP 2023', ascending=False)
escolas_bonus = escolas[escolas['IDESP 2023'] > escolas['Ouro']].sort_values(by='IDESP 2023')

escolas_diamante
# Out:
#       COD. CIE                         ESCOLA             DIRETORIA  \
# 2356    917151          Fernando Barbosa Prof            Mogi Mirim
# 2261     32347           Joao Pinheiro Correa  Mirante Paranapanema
# 52       37928          Sinesia Martini Profa             Americana
# 1434     15192                  Fonseca Major          Itapetininga
# 553     912852      Renato De Azevedo Rezende     Bragança Paulista
# ...        ...                            ...                   ...
# 2500    910995  Olinda Leite Sinisgalli Profa               Norte 1
# 1236    352585                  Bom Pastor Ii       Guarulhos Norte
# 2931     35105            Pascoal Grecco Prof              Registro
# 1502     49025          Jardim Maria Helena I               Itapevi
# 3408     23218            Willian Amin Doutor  Sao Joaquim Da Barra
#
#                  MUNICIPIO  Total     Alunos Particip.  % TPS  TPS Elegível  \
# 2356            Mogi Mirim                          25   0.93             1
# 2261  Mirante Paranapanema                          18   1.00             1
# 52               Americana                          30   0.94             1
# 1434          Itapetininga                          62   1.00             1
# 553      Bragança Paulista                          24   0.96             1
# ...                    ...                         ...    ...           ...
# 2500             São Paulo                         104   0.54             0
# 1236       Guarulhos Norte                         186   0.66             0
# 2931              Registro                          37   0.84             1
# 1502               Itapevi                         209   0.77             0
# 3408  Sao Joaquim Da Barra                          68   0.88             1
#
#       Meta IFA  % IFA  IFA Elegível  ...  IDESP Ens.\nMédio  \
# 2356      0.80   0.94             1  ...                NaN
# 2261      0.80   0.99             1  ...                NaN
# 52        0.80   0.91             1  ...                NaN
# 1434      0.80   0.93             1  ...                NaN
# 553       0.80   0.92             1  ...                NaN
# ...        ...    ...           ...  ...                ...
# 2500      0.78   0.72             0  ...               1.88
# 1236      0.76   0.73             0  ...               1.73
# 2931      0.80   0.84             1  ...               1.72
# 1502      0.78   0.76             0  ...               1.73
# 3408      0.79   0.86             1  ...               1.69
#
#       Part.  Ens Fund. (A. Iniciais)  Part. Ens. Fund. (A. Finais)  \
# 2356                              25                             0
# 2261                              18                             0
# 52                                30                             0
# 1434                              62                             0
# 553                               24                             0
# ...                              ...                           ...
# 2500                               0                             0
# 1236                               0                            60
# 2931                               0                            25
# 1502                               0                             0
# 3408                               0                             0
#
#       Part. Ensino Médio  Total Part. 2023  IDESP 2023  Ouro  Diamante   IC  \
# 2356                   0                25        8.13  7.37      7.55  1.0
# 2261                   0                18        7.96  7.01      7.17  1.0
# 52                     0                30        7.39  6.94      7.24  1.0
# 1434                   0                62        7.37  6.68      6.91  1.0
# 553                    0                24        7.36  5.17      5.44  1.0
# ...                  ...               ...         ...   ...       ...  ...
# 2500                 104               104        1.88  1.45      1.73  1.0
# 1236                 126               186        1.80  1.25      1.50  1.0
# 2931                  12                37        1.77  1.66      1.73  1.0
# 1502                 209               209        1.73  1.42      1.68  1.0
# 3408                  68                68        1.69  1.58      1.65  1.0
#
#       ICM
# 2356  1.0
# 2261  1.0
# 52    1.0
# 1434  1.0
# 553   1.0
# ...   ...
# 2500  0.0
# 1236  0.0
# 2931  1.0
# 1502  0.0
# 3408  1.0
#
# [456 rows x 22 columns]

# %%
print(f"""
Número total de escolas: {len(escolas)}
Número de escolas que receberam o bônus: {len(escolas_bonus)} ({round(len(escolas_bonus)*100/len(escolas),2)}%)
Número de escolas que receberam o bônus diamante: {len(escolas_diamante)} ({round(len(escolas_diamante)*100/len(escolas),2)}%)

Número de escolas da cidade de São Paulo: {len(escolas[escolas['MUNICIPIO']== 'São Paulo'])}
Número de escolas da cidade de São Paulo que receberam o bônus: {len(escolas_bonus[escolas_bonus['MUNICIPIO']== 'São Paulo'])}
Porcentagem de escolas da cidade de São Paulo que receberam o bônus: {round(len(escolas_bonus[escolas_bonus['MUNICIPIO']== 'São Paulo'])*100/len(escolas[escolas['MUNICIPIO']== 'São Paulo']),2)}%
""")
# Out:
# Número total de escolas: 5014
# Número de escolas que receberam o bônus: 1277 (25.47%)
# Número de escolas que receberam o bônus diamante: 456 (9.09%)
#
# Número de escolas da cidade de São Paulo: 1078
# Número de escolas da cidade de São Paulo que receberam o bônus: 347
# Porcentagem de escolas da cidade de São Paulo que receberam o bônus: 32.19%

# %% [markdown]
# ## Análise de correlação

# %%
escolas_bonus['Total     Alunos Particip.'].describe()
# Out:
# count    1277.000000
# mean      124.649961
# std        83.385866
# min         7.000000
# 25%        63.000000
# 50%       103.000000
# 75%       166.000000
# max       584.000000
# Name: Total     Alunos Particip., dtype: float64

# %%
df_cluster = escolas.drop(columns=['DIRETORIA', 'ESCOLA', 'MUNICIPIO'])
df_cluster[0:2]
# Out:
#    COD. CIE  Total     Alunos Particip.  % TPS  TPS Elegível  Meta IFA  % IFA  \
# 0     30806                          95   0.65             0      0.77   0.85
# 1     31045                          74   0.87             1      0.80   0.85
#
#    IFA Elegível  IDESP\nEns. Fund. (anos iniciais)  \
# 0             1                                NaN
# 1             1                                NaN
#
#    IDESP  Ens.\nFund. (anos finais)  IDESP Ens.\nMédio  \
# 0                               2.6               1.83
# 1                               3.2                NaN
#
#    Part.  Ens Fund. (A. Iniciais)  Part. Ens. Fund. (A. Finais)  \
# 0                               0                            47
# 1                               0                            74
#
#    Part. Ensino Médio  Total Part. 2023  IDESP 2023  Ouro  Diamante   IC  ICM
# 0                  48                95        2.21  2.49      2.83  0.0  0.0
# 1                   0                74        3.20  4.73      4.98  0.0  0.0

# %%
import plotly.graph_objects as go

# Matriz de correlações básica
corr = df_cluster.corr()

# Gráfico de calor (heatmap)
fig = go.Figure()

fig.add_trace(
    go.Heatmap(
        x = corr.columns,
        y = corr.index,
        z = np.array(corr),
        text=corr.values,
        texttemplate='%{text:.2f}',
        colorscale='viridis'))

fig.update_layout(
    height = 1000,
    width = 1000)

fig.show()

# %% [markdown]
# ## Análise de Cluster

# %%
escolas.columns
# Out:
# Index(['COD. CIE', 'ESCOLA', 'DIRETORIA', 'MUNICIPIO',
#        'Total     Alunos Particip.', '% TPS', 'TPS Elegível', 'Meta IFA',
#        '% IFA', 'IFA Elegível', 'IDESP\nEns. Fund. (anos iniciais)',
#        'IDESP  Ens.\nFund. (anos finais)', 'IDESP Ens.\nMédio',
#        'Part.  Ens Fund. (A. Iniciais)', 'Part. Ens. Fund. (A. Finais)',
#        'Part. Ensino Médio', 'Total Part. 2023', 'IDESP 2023', 'Ouro',
#        'Diamante', 'IC', 'ICM'],
#       dtype='object')

# %%
fig = px.scatter_3d(escolas_diamante,
                   x= 'Total     Alunos Particip.',
                   y= 'IDESP 2023',
                   z= '% TPS')

fig.update_layout(
    width = 1000,
    height = 1000
)

iplot(fig)

# %% [markdown]
# # Análise das notas do 2º Bimestre - 2º Ano A

# %% [markdown]
# ## Preparando os dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
import scipy.stats as stats
from scipy.stats import zscore
from scipy.spatial.distance import pdist
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
import pingouin as pg
import plotly.express as px 
import plotly.graph_objects as go
import plotly.io as pio

from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
notas = pd.read_excel('Mapão 2A.xlsx')
notas.drop(columns=[notas.columns[1],notas.columns[2]],inplace=True)
notas = notas[notas['Sit']=='At']
notas['Nome'] = [nome.split()[0] for nome in notas['Nome']]

# %%
notas['Nome']
# Out:
# 1         ALINE
# 4        ARTHUR
# 6        CARLOS
# 8          DAVI
# 9         DENIS
# 10       EMILLY
# 11        EMILY
# 12      EVERTON
# 14     GIOVANNA
# 15       GISELE
# 16    GUILHERME
# 17      GUSTAVO
# 22         JOAO
# 24      LARISSA
# 26        LUCAS
# 27        MARIA
# 33        PABLO
# 36         RUAN
# 37       SOPHIA
# 40        VITOR
# 41     ISABELLE
# 43        SARAH
# 47         CAIO
# 49    JHONATHAN
# 50        JULIA
# 51       KELVIN
# 52      MATHEUS
# 53      MONIQUE
# 54     PRICILLA
# 55      RAPHAEL
# 56     THAINARA
# 57       THALYA
# 59       DANILO
# 60        BRUNO
# 63        LYVIA
# 64          ANA
# Name: Nome, dtype: object

# %%
notas_cluster = notas.drop(columns=['Nome','Sit','ESPORTE-MÚSICA-ARTE'])

for column in notas_cluster.columns:
    notas_cluster[column] = pd.to_numeric(notas_cluster[column], errors='coerce')
    notas[column] = pd.to_numeric(notas[column], errors='coerce')

notas_cluster = notas_cluster.dropna(axis=0, how='any')
notas = notas.dropna(axis=0, how='any')

# %% [markdown]
# ## Análise de Correlação de Perason

# %%
# Matriz de correlações básica
corr = notas_cluster.corr()

# Gráfico de calor (heatmap)
fig = go.Figure()

fig.add_trace(
    go.Heatmap(
        x = corr.columns,
        y = corr.index,
        z = np.array(corr),
        text=corr.values,
        texttemplate='%{text:.2f}',
        colorscale='viridis'))

fig.update_layout(
    height = 800,
    width = 1000)

fig.show()
# Out:
# <div>                            <div id="250125ec-de25-46be-8b34-48b1833a870f" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("250125ec-de25-46be-8b34-48b1833a870f")) {                    Plotly.newPlot(                        "250125ec-de25-46be-8b34-48b1833a870f",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"text":[[1.0,0.3236950730091852,0.6652568440360364,0.592453657556859,0.7791935320378456,0.6150614079574496,0.49880606551863516,0.4954371929223713,0.19727177439119994,0.3302625170005036,0.5251301688181459,0.7111860507450664,0.664894623759143,0.5109737357974515,0.4786726611470516],[0.3236950730091852,1.0,-0.03516548468939599,0.13168032620859396,0.36701427775057316,0.09696023893275335,0.02977729769402819,0.22858718624890073,-0.004964628906120757,0.23794011651083624,0.5656334061445211,0.1303998844370301,0.4951475487246722,0.03131598371061175,0.004994885409448472],[0.6652568440360364,-0.03516548468939599,1.0,0.7402515297569304,0.6213425854018073,0.7593123743422894,0.6868016622298306,0.5800132215593775,0.3711333090661205,0.3043716653293204,0.44906482660756813,0.5001160869677534,0.6140814640317888,0.5615190733629734,0.6590150083079044],[0.592453657556859,0.13168032620859396,0.7402515297569304,1.0,0.7197829232140192,0.8371071466408802,0.6935348776393029,0.609668431683943,0.4350730466584898,0.4336501181643126,0.4475453650846699,0.36957909544776874,0.5769985676294297,0.5687621829908766,0.5643228038178801],[0.7791935320378456,0.36701427775057316,0.6213425854018073,0.7197829232140192,1.0,0.723174358980831,0.5913452888242632,0.46395826304285004,0.4060623798909468,0.4793881712657472,0.6316525138462806,0.5383598773126376,0.775142151239499,0.5907512239910957,0.4448859194400553],[0.6150614079574496,0.09696023893275335,0.7593123743422894,0.8371071466408802,0.723174358980831,1.0,0.8470676368789163,0.6388089628375486,0.4472207532916707,0.3704280543421476,0.6004398126187452,0.5217144818290141,0.7174960033341754,0.5131837546729914,0.7338973762400202],[0.49880606551863516,0.02977729769402819,0.6868016622298306,0.6935348776393029,0.5913452888242632,0.8470676368789163,1.0,0.6807062289230645,0.38557863799223796,0.3317847106528823,0.5465063501713194,0.4940935666687969,0.647137481398832,0.48999570609804954,0.668538935340856],[0.4954371929223713,0.22858718624890073,0.5800132215593775,0.609668431683943,0.46395826304285004,0.6388089628375486,0.6807062289230645,1.0,0.4234554822326476,0.6471155332160106,0.718385107054841,0.510905413217615,0.7184026409637465,0.47991819859664053,0.44375116256142094],[0.19727177439119994,-0.004964628906120757,0.3711333090661205,0.4350730466584898,0.4060623798909468,0.4472207532916707,0.38557863799223796,0.4234554822326476,1.0,0.5413513532929523,0.4137361106333147,0.4972840457019923,0.3653822199651573,0.6129576697129762,0.26134989002024456],[0.3302625170005036,0.23794011651083624,0.3043716653293204,0.4336501181643126,0.4793881712657472,0.3704280543421476,0.3317847106528823,0.6471155332160106,0.5413513532929523,1.0,0.4951947090661897,0.42055839318597443,0.5475358792202181,0.5337638644295597,0.009757524688068436],[0.5251301688181459,0.5656334061445211,0.44906482660756813,0.4475453650846699,0.6316525138462806,0.6004398126187452,0.5465063501713194,0.718385107054841,0.4137361106333147,0.4951947090661897,1.0,0.5099603062921586,0.8578301861955048,0.4625805030405214,0.41082519051627303],[0.7111860507450664,0.1303998844370301,0.5001160869677534,0.36957909544776874,0.5383598773126376,0.5217144818290141,0.4940935666687969,0.510 ...

# %% [markdown]
# ## Clusterização

# %%
fig = px.scatter_3d(notas_cluster, 
                    x='MATEMATICA', 
                    y='FISICA', 
                    z='LINGUA PORTUGUESA',
                    text=notas.Nome)
fig.update_layout(
    width = 800,
    height = 600
)
iplot(fig)
# Out:
# <div>                            <div id="772fce29-7af0-4c68-b850-a102599797f3" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("772fce29-7af0-4c68-b850-a102599797f3")) {                    Plotly.newPlot(                        "772fce29-7af0-4c68-b850-a102599797f3",                        [{"hovertemplate":"MATEMATICA=%{x}\u003cbr\u003eFISICA=%{y}\u003cbr\u003eLINGUA PORTUGUESA=%{z}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["ALINE","CARLOS","DENIS","EMILLY","EMILY","EVERTON","GIOVANNA","GISELE","GUILHERME","GUSTAVO","JOAO","LARISSA","MARIA","PABLO","RUAN","SOPHIA","VITOR","ISABELLE","SARAH","CAIO","JHONATHAN","JULIA","MONIQUE","PRICILLA","RAPHAEL","THAINARA","THALYA","DANILO","BRUNO"],"x":[5.0,8.0,5.0,7.0,4.0,4.0,7.0,8.0,4.0,10.0,5.0,6.0,10.0,6.0,3.0,3.0,6.0,2.0,5.0,8.0,6.0,6.0,10.0,5.0,6.0,5.0,6.0,5.0,4.0],"y":[7.0,5.0,6.0,9.0,3.0,4.0,8.0,8.0,2.0,8.0,3.0,4.0,9.0,5.0,1.0,2.0,5.0,4.0,4.0,5.0,1.0,8.0,8.0,3.0,5.0,7.0,3.0,4.0,4.0],"z":[6.0,6.0,5.0,8.0,6.0,6.0,6.0,8.0,5.0,9.0,7.0,5.0,8.0,7.0,6.0,8.0,7.0,7.0,5.0,6.0,6.0,8.0,9.0,6.0,9.0,6.0,6.0,5.0,5.0],"type":"scatter3d"}],                        {"height":600,"legend":{"tracegroupgap":0},"margin":{"t":60},"scene":{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"xaxis":{"title":{"text":"MATEMATICA"}},"yaxis":{"title":{"text":"FISICA"}},"zaxis":{"title":{"text":"LINGUA PORTUGUESA"}}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...

# %%
fig = px.scatter_3d(notas_cluster, 
                    x='MATEMATICA', 
                    y='EDUCACAO FISICA', 
                    z='LINGUA PORTUGUESA',
                    text=notas.Nome)
fig.update_layout(
    width = 800,
    height = 600
)
iplot(fig)
# Out:
# <div>                            <div id="0f51900a-70ff-4e15-875d-2e19f4bfe645" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f51900a-70ff-4e15-875d-2e19f4bfe645")) {                    Plotly.newPlot(                        "0f51900a-70ff-4e15-875d-2e19f4bfe645",                        [{"hovertemplate":"MATEMATICA=%{x}\u003cbr\u003eEDUCACAO FISICA=%{y}\u003cbr\u003eLINGUA PORTUGUESA=%{z}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["ALINE","CARLOS","DENIS","EMILLY","EMILY","EVERTON","GIOVANNA","GISELE","GUILHERME","GUSTAVO","JOAO","LARISSA","MARIA","PABLO","RUAN","SOPHIA","VITOR","ISABELLE","SARAH","CAIO","JHONATHAN","JULIA","MONIQUE","PRICILLA","RAPHAEL","THAINARA","THALYA","DANILO","BRUNO"],"x":[5.0,8.0,5.0,7.0,4.0,4.0,7.0,8.0,4.0,10.0,5.0,6.0,10.0,6.0,3.0,3.0,6.0,2.0,5.0,8.0,6.0,6.0,10.0,5.0,6.0,5.0,6.0,5.0,4.0],"y":[9.0,10.0,8.0,9.0,8.0,6.0,9.0,9.0,9.0,9.0,9.0,7.0,9.0,10.0,9.0,9.0,9.0,9.0,7.0,9.0,9.0,9.0,9.0,9.0,9.0,6.0,9.0,8.0,10.0],"z":[6.0,6.0,5.0,8.0,6.0,6.0,6.0,8.0,5.0,9.0,7.0,5.0,8.0,7.0,6.0,8.0,7.0,7.0,5.0,6.0,6.0,8.0,9.0,6.0,9.0,6.0,6.0,5.0,5.0],"type":"scatter3d"}],                        {"height":600,"legend":{"tracegroupgap":0},"margin":{"t":60},"scene":{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"xaxis":{"title":{"text":"MATEMATICA"}},"yaxis":{"title":{"text":"EDUCACAO FISICA"}},"zaxis":{"title":{"text":"LINGUA PORTUGUESA"}}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888, ...

# %% [markdown]
# ### Cluster - Distância euclidiana - single linkage

# %%
plt.figure(figsize=(16,9))
dend_sing = sch.linkage(notas_cluster, method = 'single', metric = 'euclidean')

# Opções para o método de encadeamento ("method"):
    ## single
    ## complete
    ## average
treshold = 6.6
dendrogram_s = sch.dendrogram(dend_sing, color_threshold = treshold, labels = list(notas.Nome))
plt.title('Dendrograma', fontsize=16)
plt.xlabel('Pessoas', fontsize=16)
plt.ylabel('Distância Euclidiana - Single', fontsize=16)
# a altura vermelha representa uma altura que se pode encerrar o esquema de aglomeração
plt.axhline(y = treshold, color = 'red', linestyle = '--')

plt.show()

# %%
plt.figure(figsize=(20,9))
dend_comp = sch.linkage(notas_cluster, method = 'complete', metric = 'euclidean')

# Opções para o método de encadeamento ("method"):
    ## single
    ## complete
    ## average
treshold = 9.5
dendrogram_s = sch.dendrogram(dend_comp, color_threshold = treshold, labels = list(notas.Nome))
plt.title('Dendrograma', fontsize=16)
plt.xlabel('Pessoas', fontsize=16)
plt.ylabel('Distância Euclidiana - Complete', fontsize=16)
# a altura vermelha representa uma altura que se pode encerrar o esquema de aglomeração
plt.axhline(y = treshold, color = 'red', linestyle = '--')

plt.show()

# %%
plt.figure(figsize=(20,9))
dend_av = sch.linkage(notas_cluster, method = 'average', metric = 'euclidean')

# Opções para o método de encadeamento ("method"):
    ## single
    ## complete
    ## average
treshold = 7.6
dendrogram_s = sch.dendrogram(dend_av, color_threshold = treshold, labels = list(notas.Nome))
plt.title('Dendrograma', fontsize=16)
plt.xlabel('Pessoas', fontsize=16)
plt.ylabel('Distância Euclidiana - Average', fontsize=16)
# a altura vermelha representa uma altura que se pode encerrar o esquema de aglomeração
plt.axhline(y = treshold, color = 'red', linestyle = '--')

plt.show()

# %% [markdown]
# ### Gerando a variável de indicação de cluster

# %%
cluster_complete = AgglomerativeClustering(n_clusters=7, metric='euclidean', linkage='complete')
indica_cluster_complete = cluster_complete.fit_predict(notas_cluster)
notas['Cluster Complete'] = indica_cluster_complete
notas['Cluster Complete'] = notas['Cluster Complete'].astype('category')
notas
# Out:
#          Nome Sit  LINGUA PORTUGUESA  EDUCACAO FISICA  GEOGRAFIA  HISTORIA  \
# 1       ALINE  At                6.0              9.0        2.0       4.0
# 6      CARLOS  At                6.0             10.0        2.0       4.0
# 9       DENIS  At                5.0              8.0        3.0       5.0
# 10     EMILLY  At                8.0              9.0        8.0       7.0
# 11      EMILY  At                6.0              8.0        7.0       4.0
# 12    EVERTON  At                6.0              6.0        3.0       3.0
# 14   GIOVANNA  At                6.0              9.0        8.0       8.0
# 15     GISELE  At                8.0              9.0       10.0       7.0
# 16  GUILHERME  At                5.0              9.0        2.0       3.0
# 17    GUSTAVO  At                9.0              9.0       10.0      10.0
# 22       JOAO  At                7.0              9.0        4.0       4.0
# 24    LARISSA  At                5.0              7.0        2.0       5.0
# 27      MARIA  At                8.0              9.0       10.0       7.0
# 33      PABLO  At                7.0             10.0        2.0       4.0
# 36       RUAN  At                6.0              9.0        2.0       5.0
# 37     SOPHIA  At                8.0              9.0        4.0       4.0
# 40      VITOR  At                7.0              9.0        2.0       4.0
# 41   ISABELLE  At                7.0              9.0        3.0       4.0
# 43      SARAH  At                5.0              7.0        8.0       4.0
# 47       CAIO  At                6.0              9.0        3.0       2.0
# 49  JHONATHAN  At                6.0              9.0        2.0       5.0
# 50      JULIA  At                8.0              9.0        8.0       9.0
# 53    MONIQUE  At                9.0              9.0       10.0       9.0
# 54   PRICILLA  At                6.0              9.0        3.0       4.0
# 55    RAPHAEL  At                9.0              9.0        8.0       4.0
# 56   THAINARA  At                6.0              6.0        6.0       5.0
# 57     THALYA  At                6.0              9.0        3.0       4.0
# 59     DANILO  At                5.0              8.0        1.0       4.0
# 60      BRUNO  At                5.0             10.0        3.0       4.0
#
#     SOCIOLOGIA  BIOLOGIA  FISICA  MATEMATICA  QUIMICA  ORIENTACAO DE ESTUDOS  \
# 1          8.0       7.0     7.0         5.0      9.0                    8.0
# 6          5.0       5.0     5.0         8.0      4.0                    7.0
# 9          5.0       6.0     6.0         5.0      7.0                    7.0
# 10         8.0       9.0     9.0         7.0      4.0                    8.0
# 11         4.0       5.0     3.0         4.0      4.0                    4.0
# 12         3.0       5.0     4.0         4.0      3.0                    5.0
# 14         7.0       8.0     8.0         7.0      9.0                    9.0
# 15         8.0       7.0     8.0         8.0      4.0                    9.0
# 16         5.0       5.0     2.0         4.0      1.0                    4.0
# 17        10.0      10.0     8.0        10.0     10.0                   10.0
# 22         6.0       5.0     3.0         5.0      3.0                    5.0
# 24         5.0       5.0     4.0         6.0      9.0                    8.0
# 27         8.0      10.0     9.0        10.0      9.0                    9.0
# 33         5.0       5.0     5.0         6.0      4.0                    7.0
# 36         5.0       5.0     1.0         3.0      5.0                    8.0
# 37         8.0       5.0     2.0         3.0      4.0                    8.0
# 40         5.0       5.0     5.0         6.0      7.0                    8.0
# 41         5.0       6.0     4.0         2.0      5.0                    1.0
# 43         3.0       5.0     4.0         5.0      9.0                    7.0
# 47         3.0       5.0     5.0         8.0      6.0                    8.0
# 49         3.0       5.0     1.0         6.0      6.0                    8.0
# 50        10.0       8.0     8.0         6.0      8.0                    7.0
# 53        10.0       8.0     8.0        10.0      7.0                    9.0
# 54         7.0       6.0     3.0         5.0      7.0                    9.0
# 55         9.0       6.0     5.0         6.0      8.0                    9.0
# 56         5.0       7.0     7.0         5.0      5.0                    5.0
# 57         7.0       5.0     3.0         6.0      9.0                    9.0
# 59         4.0       5.0     4.0         5.0      2.0                    8.0
# 60         5.0       5.0     4.0         4.0      5.0                    6.0
#
#     PROJETO DE VIDA  EDUCAÇÃO FINANCEIRA  REDAÇÃO E LEITURA  \
# 1               9.0                  9.0                9.0
# 6               8.0                  5.0                7.0
# 9               5.0                  3.0                5.0
# 10              8.0                  6.0               10.0
# 11              6.0                  7.0                5.0
# 12              5.0                  5.0                5.0
# 14              8.0                  5.0                8.0
# 15              8.0                  7.0               10.0
# 16              8.0                  1.0                7.0
# 17             10.0                 10.0               10.0
# 22              6.0                  5.0                7.0
# 24              6.0                  5.0                6.0
# 27             10.0                  9.0               10.0
# 33              8.0                  5.0                7.0
# 36              6.0                  5.0                5.0
# 37              6.0                  7.0                7.0
# 40              8.0                  8.0                6.0
# 41              6.0                  5.0                6.0
# 43              6.0                  4.0                6.0
# 47              8.0                  9.0                8.0
# 49              6.0                  5.0                6.0
# 50              7.0                  8.0                8.0
# 53             10.0                  7.0               10.0
# 54              8.0                  5.0                8.0
# 55              8.0                  9.0                8.0
# 56              6.0                  6.0                5.0
# 57              8.0                  5.0                8.0
# 59              5.0                  3.0                5.0
# 60              8.0                  3.0                7.0
#
#    ESPORTE-MÚSICA-ARTE  INGLÊS  PRATICAS EXPERIMENTAIS Cluster Complete
# 1                   ES     5.0                     6.0                3
# 6                   ES     5.0                     5.0                0
# 9                   ES     5.0                     5.0                6
# 10                  ES     5.0                     8.0                4
# 11                  ES     5.0                     5.0                2
# 12                  ES     3.0                     5.0                1
# 14                  ES     7.0                     8.0                4
# 15                  ES     8.0                     6.0                4
# 16                  ES     4.0                     6.0                1
# 17                  ES    10.0                     6.0                5
# 22                  ES     0.0                     5.0                1
# 24                  ES     7.0                     6.0                6
# 27                  ES     6.0                    10.0                5
# 33                  ES     5.0                     5.0                0
# 36                  ES     5.0                     4.0                1
# 37                  ES     5.0                     4.0                0
# 40                  ES     7.0                     4.0                0
# 41                  ES     5.0                     8.0                2
# 43                  ES     6.0                     6.0                6
# 47                  ES     4.0                     5.0                0
# 49                  ES     3.0                     5.0                1
# 50                  ES     7.0                     7.0                4
# 53                  ET     7.0                     9.0                5
# 54                  ET     6.0                     5.0                0
# 55                  ET     9.0                     7.0                3
# 56                  ES     5.0                     6.0                2
# 57                  ET     6.0                     2.0                0
# 59                  ES     4.0                     4.0                1
# 60                  ES     2.0                     4.0                1

# %%
fig = px.scatter_3d(notas, 
                    x='MATEMATICA', 
                    y='EDUCACAO FISICA', 
                    z='LINGUA PORTUGUESA',
                    color= 'Cluster Complete',
                    text=notas.Nome)
fig.update_layout(
    width = 800,
    height = 600
)
iplot(fig)

# %%
fig = px.scatter_3d(notas, 
                    x='MATEMATICA', 
                    y='FISICA', 
                    z='QUIMICA',
                    color= 'Cluster Complete',
                    text=notas.Nome)
fig.update_layout(
    width = 800,
    height = 600
)
iplot(fig)

# %%
fig = px.scatter_3d(notas, 
                    x='SOCIOLOGIA', 
                    y='HISTORIA', 
                    z='GEOGRAFIA',
                    color= 'Cluster Complete',
                    text=notas.Nome)
fig.update_layout(
    width = 800,
    height = 600
)
iplot(fig)

# %% [markdown]
# # Análise - Dados eleitorais

# %% [markdown]
# ## Preparando os dados

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

prefeito = pd.read_excel('Dados_PrefVer_BeloHorz_MG.xlsx')
prefeito[0:5]
# Out:
#    DS_CARGO                 NM_VOTAVEL  \
# 0  Prefeito           NILMÁRIO MIRANDA
# 1  Prefeito               BRUNO ENGLER
# 2  Prefeito  PROFESSOR WENDEL MESQUITA
# 3  Prefeito          LAFAYETTE ANDRADA
# 4  Prefeito                     Branco
#
#                                  NM_PARTIDO  QT_VOTOS
# 0                 Partido dos Trabalhadores        15
# 1  Partido Renovador Trabalhista Brasileiro        43
# 2                             Solidariedade         2
# 3                              REPUBLICANOS         1
# 4                                    #NULO#         8

# %%
vereador = pd.read_excel('Dados_PrefVer_BeloHorz_MG.xlsx', sheet_name=1)
vereador[0:5]
# Out:
#    DS_CARGO                 NM_VOTAVEL                      NM_PARTIDO  \
# 0  Vereador           GABRIEL SAPUCAIA                    Partido Novo
# 1  Vereador                LUCAS SILVA                    Partido Novo
# 2  Vereador           WELLINGTON RAMOS                   Solidariedade
# 3  Vereador  JUNIOR BRASIL DA ITATIAIA  Partido Trabalhista Brasileiro
# 4  Vereador           KEILA JACQUELINE           Rede Sustentabilidade
#
#    QT_VOTOS
# 0         3
# 1         1
# 2         1
# 3         1
# 4         1

# %%
vereador.shape[0]
# Out:
# 440610

# %%
vereador.drop(columns='DS_CARGO',inplace=True)
vereador['NM_VOTAVEL'].value_counts()
# Out:
# NM_VOTAVEL
# Branco                      3491
# Nulo                        3490
# PSD                         3429
# NIKOLAS FERREIRA            3423
# PROFESSORA DUDA SALABERT    3418
#                             ...
# BIANCA ANGEL                   1
# MARIA FRANCISCA                1
# DONA CONCEIÇÃO                 1
# TIA LEIDE                      1
# JULIANA SANTANA                1
# Name: count, Length: 1531, dtype: int64

# %%
votos_vereador = vereador.groupby(['NM_VOTAVEL','NM_PARTIDO']).sum()
votos_vereador.to_excel('Votos por vereador.xlsx')

# %%
prefeito.shape

# %%
prefeito.info()

# %%
prefeito['DS_CARGO'].value_counts()

# %%
prefeito.drop(columns='DS_CARGO', inplace=True)

# %%
votos_prefeito = prefeito.groupby(['NM_VOTAVEL', 'NM_PARTIDO']).sum()
votos_prefeito.to_excel('Votos por prefeito.xlsx')
