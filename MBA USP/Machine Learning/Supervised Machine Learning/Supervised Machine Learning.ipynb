# %% [markdown]
# # Supervised Machine Learning
#
# Os Modelos Supervisionados em Machine Learning fazem predições acerca de um comportamento com base em um conjunto de dados. Essas predições são simplificações da realidade, e necessariamente omitem ou distorcem informações acerca da mesma.
#
# Nos modelos GLM (Generalized Linear Model) ou Modelos Supervisionados, temos a variável dependente $Y$ que seria o outcome do modelo, e a variável $X_1$, $X_2$, $X_3$,...$X_k$ as variáveis explicativas (ou independentes como chamadas em algumas fontes). Temos que $Y=f(X_1, X_2, X_3, ..., X_k)$
#
# Abaixo segue uma tabela sobre alguns modelos supervisionados:
#
#
# \begin{array}{|c|c|c|}
# \hline
# \textbf{Modelo de Regressão} & \textbf{Característica da Variável Dependente} & \textbf{Distribuição} \\
# \hline
# \text{Linear} & \text{Quantitativa} & \text{Normal} \\
# \text{Com transformação de Box-Cox} & \text{Quantitativa} & \text{Normal Após a Transformação}\\
# \text{Logística Binária} & \text{Qualitativa com 2 Categorias (Dummy)} & \text{Bernoulli}\\
# \text{Logística Multinomial} & \text{Qualitativa M (M > 2) Categorias} & \text{Binomial}\\
# \text{Poisson} & \text{Quantitatica com Valores Inteiros e Não Negativos (Dados de Contagem)} & \text{Poisson}\\
# \text{Binomial Negativo} & \text{Quantitativa com valores inteiros e não negativos (dados de contagem)} & \text{Poisson-Gama}\\
# \hline
# \end{array}

# %% [markdown]
# # 1 - Supervised Machine Learning: Regressão Linear Simples
#
# O objetivo é desenvolver uma equação linear que apresente a relação entre uma variável dependente e uma variável explicativa.
#
# **Equação geral da reta:**
#
# \begin{equation}
# Y - Y_0 = m(X - X_0)
# \end{equation}
#
# \begin{equation}
# Y = Y_0 - m.X_0 + m.X
# \end{equation}
#
# Considerando $Y_0 - m.X_0 = \alpha$ e $m=\beta$, então temos:
#
# $Y_i = \alpha + \beta.X_i + u$
#
# Onde:
#
# $Y_i=$ Valor da i-ésima observação da variável dependente para o i-ésimo dado
# $\alpha = $ intercepto\
# $\beta = $ coeficiente de inclinação \
# $\alpha = $intercepto. Ponto que intercepta o eixo Y quando $x=0$\
# $u = Y_i - \hat{Y}_i$ termo de erro onde $\hat{Y}_i$ é o valor previsto para o ponto $Y_i$
#
#
# Nessa técnica, existe uma variável chamada de $R^2$ que é chamada de coeficiente de determinação (ou coeficiente de ajuste, explicação) que representa o peso que uma variável tem na variação de outra variável. Exemplo: a distância tem um coeficiente de determinação alto em relação a explicar o tempo que se leva para fazer um trajeto.
#
# **Ajuste de uma reta aos pontos**
#
# Existem algumas condições necessárias para se ajustar uma reta a um conjunto de pontos:
#
# 1. $\sum^{n}_{i=1} u_i = 0$
# 2. $min(\sum^{n}_{i=1} (u_i)^2)$
#
# Esse é conhecido como o método dos *Mínimos Quadrados Ordinários* MQO
#
# **O que é o $ R^2 $ na Análise de Regressão?**
#
# O $ R^2 $, também conhecido como **coeficiente de determinação**, é uma medida estatística que indica a proporção da variância na variável dependente ($ Y $) que é explicada pela variável independente ($ X $) no modelo de regressão. Ele varia entre 0 e 1 e fornece uma indicação de quão bem os dados observados se ajustam ao modelo de regressão.
#
# - **$ R^2 = 1 $**: Indica que o modelo de regressão explica perfeitamente a variação em $ Y $.
# - **$ R^2 = 0 $**: Indica que o modelo de regressão não explica nenhuma variação em $ Y $.
#
# **Como Interpretar o $ R^2 $**
#
# - Um $ R^2 $ mais próximo de 1 indica que o modelo faz um bom trabalho em explicar a variação em $ Y $ com base em $ X $.
# - Um $ R^2 $ próximo de 0 indica que o modelo não explica bem a variação em $ Y $, e outros fatores não incluídos no modelo podem estar influenciando $ Y $.
#
# **Como Calcular o $ R^2 $?**
#
# O $ R^2 $ é calculado com base nas seguintes fórmulas:
#
# **1. **Resíduos ao Quadrado (SSE - Soma dos Quadrados dos Erros)**
# A soma dos quadrados dos resíduos, $ SSE $, mede a variação que o modelo de regressão não consegue explicar:
#
# $
# SSE = \sum_{i=1}^{n} (Y_i - \hat{Y_i})^2
# $
#
# onde:
# - $ Y_i $ é o valor observado da variável dependente.
# - $ \hat{Y_i} $ é o valor predito pela equação de regressão.
#
# **Soma Total dos Quadrados (SST - Total Sum of Squares)**
# A soma total dos quadrados, $ SST $, mede a variação total em $ Y $ em relação à média de $ Y $:
#
# $
# SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2
# $
#
# onde:
# - $ \bar{Y} $ é a média dos valores observados de $ Y $.
#
# **Soma dos Quadrados Explicada (SSR - Regression Sum of Squares)**
# A soma dos quadrados explicada, $ SSR $, mede a variação que o modelo de regressão consegue explicar:
#
# $
# SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2
# $
#
# **Fórmula para $ R^2 $**
#
# O $ R^2 $ pode ser calculado de duas maneiras equivalentes:
#
# 1. Como a razão entre a soma dos quadrados explicada e a soma total dos quadrados:
# $
# R^2 = \frac{SSR}{SST}
# $
#
# 2. Ou como 1 menos a razão entre a soma dos quadrados dos erros e a soma total dos quadrados:
# $
# R^2 = 1 - \frac{SSE}{SST}
# $
#
# ---
# **Exemplo de Cálculo do $ R^2 $**
#
# Suponha que você tem os seguintes dados para $ Y_i $ (valores observados), $ \hat{Y_i} $ (valores preditos pelo modelo) e $ \bar{Y} $ (média de $ Y $):
#
# - $ Y_i $ = [3, 5, 7, 9]
# - $ \hat{Y_i} $ = [2.8, 5.1, 6.9, 9.2]
# - $ \bar{Y} $ = 6
#
# **Passo 1**: Calcular $ SSE $:
#
# $
# SSE = (3 - 2.8)^2 + (5 - 5.1)^2 + (7 - 6.9)^2 + (9 - 9.2)^2 = 0.04 + 0.01 + 0.01 + 0.04 = 0.1
# $
#
# **Passo 2**: Calcular $ SST $:
#
# $
# SST = (3 - 6)^2 + (5 - 6)^2 + (7 - 6)^2 + (9 - 6)^2 = 9 + 1 + 1 + 9 = 20
# $
#
# **Passo 3**: Calcular $ R^2 $:
#
# $
# R^2 = 1 - \frac{SSE}{SST} = 1 - \frac{0.1}{20} = 1 - 0.005 = 0.995
# $
#
# Neste exemplo, $R^2 = 0.995$, indicando que o modelo de regressão explica 99,5% da variação em $ Y $.
#
# **Conclusão**
#
# O  $R^2$ é uma medida crucial para avaliar a qualidade do ajuste de um modelo de regressão. Ele indica a proporção da variação total em $Y$ que é explicada pela variável $X$ no modelo. Um valor de $R^2$ mais alto indica um modelo que melhor explica a variabilidade dos dados observados. Em resumo, quanto menor a dispersão dos dados em torno do ajuste, maior o valor de $R^2$.
#
# ---
#
# Apenas o parâmetro $R^2$ não é suficiente para verificar se o ajuste tem significância estatística.

# %% [markdown]
# ## 1.1 - Implementação no Python

# %% [markdown]
# ### 1.1.1 - Preparando os dados

# %% [raw]
# !pip install pandas
# !pip install numpy
# !pip install -U seaborn
# !pip install matplotlib
# !pip install plotly
# !pip install scipy
# !pip install statsmodels
# !pip install scikit-learn
# !pip install playsound
# !pip install pingouin
# !pip install emojis
# !pip install statstests

# %%
import pandas as pd # manipulação de dados em formato de dataframe
import numpy as np # operações matemáticas
import seaborn as sns # visualização gráfica
import matplotlib.pyplot as plt # visualização gráfica
import plotly.graph_objects as go # gráficos 3D
from scipy.stats import pearsonr # correlações de Pearson
import statsmodels.api as sm # estimação de modelos
from statsmodels.iolib.summary2 import summary_col # comparação entre modelos
from sklearn.preprocessing import LabelEncoder # transformação de dados
from playsound import playsound # reprodução de sons
import pingouin as pg # outro modo para obtenção de matrizes de correlações
import emojis # inserção de emojis em gráficos
from statstests.process import stepwise # procedimento Stepwise
from statstests.tests import shapiro_francia # teste de Shapiro-Francia
from scipy.stats import boxcox # transformação de Box-Cox
from scipy.stats import norm # para plotagem da curva normal
from scipy import stats # utilizado na definição da função 'breusch_pagan_test'

# %%
df_tempodist = pd.read_csv('tempodist.csv', delimiter=',')
df_tempodist[0:5]
# Out:
#    tempo  distancia
# 0     15          8
# 1     20          6
# 2     20         15
# 3     40         20
# 4     50         25

# %%
# Características das variáveis do dataset
df_tempodist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tempo      10 non-null     int64
#  1   distancia  10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
# Estatísticas univariadas
df_tempodist.describe()
# Out:
#           tempo  distancia
# count  10.00000  10.000000
# mean   30.00000  17.000000
# std    14.90712   9.510228
# min    10.00000   5.000000
# 25%    20.00000   8.750000
# 50%    27.50000  17.500000
# 75%    38.75000  23.750000
# max    55.00000  32.000000

# %% [markdown]
# ### 1.1.2 - Criando o gráfico de dispersão

# %%
# In[1.1]: Gráfico de dispersão com o ajuste linear (fitted values de um modelo
#de regressão) que se adequa às observações: função 'regplot' do pacote 'seaborn'

plt.figure(figsize=(15,10))
sns.regplot(data=df_tempodist, x='distancia', y='tempo', marker='o', ci=False,
            scatter_kws={"color":'navy', 'alpha':0.9, 's':220},
            line_kws={"color":'grey', 'linewidth': 5})
plt.title('Valores Reais e Fitted Values (Modelo de Regressão)', fontsize=30)
plt.xlabel('Distância', fontsize=24)
plt.ylabel('Tempo', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0, 35)
plt.ylim(0, 60)
plt.legend(['Valores Reais', 'Fitted Values'], fontsize=24, loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# In[1.2]: Gráfico de dispersão interativo (figura 'EXEMPLO1.html' salva na
#pasta do curso)

# Dados do gráfico
x = df_tempodist['distancia']
y = df_tempodist['tempo']

# Definição da regressão linear
slope, intercept = np.polyfit(x, y, 1)
y_trend = slope * x + intercept

fig = go.Figure()

# Inserção dos pontos (valores reais)
fig.add_trace(go.Scatter(
    x=x,
    y=y,
    mode='markers',
    marker=dict(color='navy', size=20), name='Valores Reais')
    )

# Inserção da reta (fitted values)
fig.add_trace(go.Scatter(
    x=x,
    y=y_trend,
    mode='lines',
    line=dict(color='dimgray', width=5), name='Fitted Values')
    )

# Configurações de layout
fig.update_layout(
    xaxis_title='Distância',
    yaxis_title='Tempo',
    title={
        'text': 'Gráfico de Dispersão com Fitted Values',
        'font': {'size': 20, 'color': 'black', 'family': 'Arial'},
        'x': 0.5,
        'y': 0.97,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    plot_bgcolor='snow',
    xaxis=dict(gridcolor='black'),
    yaxis=dict(gridcolor='black'),
    showlegend=True
)

fig.write_html('EXEMPLO1.html')

# Abrir o arquivo HTML no navegador
import webbrowser
webbrowser.open('EXEMPLO1.html')
# Out:
# True

# %% [markdown]
# **Nota**: Vale ressaltar que a regressão linear simples, nem sempre consegue ajustar pontos fora do intervalo de treinamento. Exemplo: Seguindo o ajuste linear, um valor para $\text{distância}=0$ levaria um tempo $t>0$, o que não corresponde à realidade.

# %% [markdown]
# ### 1.1.3 - Estimação do modelo de regressão linear simples

# %%
# In[1.3]: Estimação do modelo de regressão linear simples

# Estimação do modelo
modelo = sm.OLS.from_formula('tempo ~ distancia', df_tempodist).fit()

# Observação dos parâmetros resultantes da estimação
modelo.summary()
# Out:
# C:\Users\Lucas Rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning:
#
# kurtosistest only valid for n>=20 ... continuing anyway, n=10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  tempo   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     36.30
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):           0.000314
# Time:                        20:31:39   Log-Likelihood:                -32.123
# No. Observations:                  10   AIC:                             68.25
# Df Residuals:                       8   BIC:                             68.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.8784      4.532      1.297      0.231      -4.573      16.330
# distancia      1.4189      0.235      6.025      0.000       0.876       1.962
# ==============================================================================
# Omnibus:                        1.016   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.602   Jarque-Bera (JB):                0.694
# Skew:                          -0.262   Prob(JB):                        0.707
# Kurtosis:                       1.820   Cond. No.                         41.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 1.1.4 - Avaliando o modelo de regressão

# %% [markdown]
# Aqui podemos ver alguns parâmetros importantes:
#
# $\alpha=5.88$\
# $\beta=1.42$\
# $R^2=0.82$
#
# Vale ressaltar que apenas os valores de $\alpha$, $\beta$ e $R^2$ **não são suficientes** para dizer se o ajuste é estatísticamente significativo. Para verificar se o ajuste é adequado, devemos olhar o resultado do **teste F**. Para isso olhamos a probabilidade da estatística F, se
#
# Prob (F-statistic) $<= 0.05$ então o ajuste é estatísticamente significativo.

# %% [markdown]
# ### 1.1.5 - Criando os plots da regressão

# %%
# In[1.4]: Salvando fitted values (variável yhat) e residuals (variável erro)
#no dataset

df_tempodist['yhat'] = modelo.fittedvalues
df_tempodist['erro'] = modelo.resid
df_tempodist
# Out:
#    tempo  distancia       yhat       erro
# 0     15          8  17.229730  -2.229730
# 1     20          6  14.391892   5.608108
# 2     20         15  27.162162  -7.162162
# 3     40         20  34.256757   5.743243
# 4     50         25  41.351351   8.648649
# 5     25         11  21.486486   3.513514
# 6     10          5  12.972973  -2.972973
# 7     55         32  51.283784   3.716216
# 8     35         28  45.608108 -10.608108
# 9     30         20  34.256757  -4.256757

# %%
# In[1.5]: Gráfico didático para visualizar o conceito de R²

plt.figure(figsize=(15,10))
y = df_tempodist['tempo']
yhat = df_tempodist['yhat']
x = df_tempodist['distancia']
mean = np.full(x.shape[0] , y.mean(), dtype=int)

for i in range(len(x)-1):
    plt.plot(x, yhat, color='grey', linewidth=7)
    plt.plot([x[i], x[i]], [yhat[i], mean[i]], '--', color='darkorchid', linewidth=5)
    plt.plot([x[i], x[i]], [yhat[i], y[i]],':', color='limegreen', linewidth=5)
    plt.scatter(x, y, color='navy', s=220, alpha=0.2)
    plt.axhline(y = y.mean(), color = 'silver', linestyle = '-', linewidth=4)
    plt.title('R²: ' + str(round(modelo.rsquared, 4)), fontsize=30)
    plt.xlabel('Distância', fontsize=24)
    plt.ylabel('Tempo', fontsize=24)
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    plt.xlim(0, 35)
    plt.ylim(0, 60)
    plt.legend(['Fitted Values', 'Ychapéu - Ymédio', 'Erro = Y - Ychapéu'],
               fontsize=22, loc='upper left')
plt.show()

# %%
# In[1.6]: Cálculo manual do R²

R2 = ((df_tempodist['yhat']-
       df_tempodist['tempo'].mean())**2).sum()/(((df_tempodist['yhat']-
                                        df_tempodist['tempo'].mean())**2).sum()+
                                        (df_tempodist['erro']**2).sum())

round(R2,4)
# Out:
# 0.8194

# %%
# In[1.7]: Coeficiente de ajuste (R²) é a correlação ao quadrado

# Correlação de Pearson
df_tempodist[['tempo','distancia']].corr()

# R²
(df_tempodist[['tempo','distancia']].corr())**2

# R² de maneira direta
modelo.rsquared
# Out:
# 0.8194256756756757

# %%
# In[1.8]: Modelo auxiliar para mostrar R² igual a 100% (para fins didáticos)

# Estimação do modelo com yhat como variável dependente resultará em um modelo
#com R² igual a 100%
modelo_auxiliar = sm.OLS.from_formula('yhat ~ distancia', df_tempodist).fit()

# Parâmetros resultantes da estimação deste modelo didático
modelo_auxiliar.summary()
# Out:
# C:\Users\Lucas Rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning:
#
# kurtosistest only valid for n>=20 ... continuing anyway, n=10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yhat   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.598e+31
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):          1.72e-122
# Time:                        20:31:40   Log-Likelihood:                 309.16
# No. Observations:                  10   AIC:                            -614.3
# Df Residuals:                       8   BIC:                            -613.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.8784   6.83e-15   8.61e+14      0.000       5.878       5.878
# distancia      1.4189   3.55e-16      4e+15      0.000       1.419       1.419
# ==============================================================================
# Omnibus:                       13.263   Durbin-Watson:                   0.046
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                1.667
# Skew:                           0.000   Prob(JB):                        0.435
# Kurtosis:                       1.000   Cond. No.                         41.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# In[1.9]:Gráfico mostrando o perfect fit

plt.figure(figsize=(15,10))
sns.scatterplot(data=df_tempodist, x='distancia', y='yhat',
                color='navy', alpha=0.9, s=300)
sns.regplot(data=df_tempodist, x='distancia', y='yhat', ci=False, scatter=False,
            label='Fitted Values',
            line_kws={"color":'grey', 'linewidth': 5})
plt.title('Perfect Fit', fontsize=30)
plt.xlabel('Distância', fontsize=24)
plt.ylabel('Tempo', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0, 35)
plt.ylim(0, 60)
plt.legend(loc='upper left', fontsize=24)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 1.2 - Análise do ajuste de regressão linear simples

# %% [markdown]
# ### 1.2.1 - Identificação dos parâmetros

# %% [markdown]
# Somatória dos quadrados do modelo

# %%
modelo.params
# Out:
# Intercept    5.878378
# distancia    1.418919
# dtype: float64

# %%
modelo.ess # errors sum square
# Out:
# 1638.8513513513512

# %%
modelo.ssr
# Out:
# 361.14864864864865

# %%
n = modelo.nobs
n
# Out:
# 10.0

# %%
df_modelo = modelo.df_model
df_modelo
# Out:
# 1.0

# %%
df_residuos = modelo.df_resid
df_residuos
# Out:
# 8.0

# %% [markdown]
# ### 1.2.2 - Cálculo da estatística F de Fisher/Snedecor

# %%
F = ((modelo.ess)/df_modelo)/((modelo.ssr)/df_residuos)
F
# Out:
# 36.30308699719364

# %% [markdown]
# ### 1.2.3 - Análise da variância

# %%
from statsmodels.stats.anova import anova_lm

anova_lm(modelo)
# Out:
#             df       sum_sq      mean_sq          F    PR(>F)
# distancia  1.0  1638.851351  1638.851351  36.303087  0.000314
# Residual   8.0   361.148649    45.143581        NaN       NaN

# %% [markdown]
# ### 1.2.4 - Interpretação da estatística F de Fisher

# %% [markdown]
# Se:
#
# - $F_{\text{calc}}>= F_{\text{crít}} \rightarrow H_1$ é aceito
#     * p-value $<= 0,05$
#     * pelo menos um valor de $\beta$ é estatísticamente significativo ($\neq 0$)
#
# - $F_{\text{calc}} < F_{\text{crít}} \rightarrow H_0$ é aceito
#     * p-value $> 0,05$
#     * $\beta_1 = \beta_2 = ... = \beta_k = 0$
#     * Não há modelo
#
# Para saber quais valores de $\beta$ são estatísticamente significativos, precisamos utilizar o **teste t**.

# %% [markdown]
# #### 1.2.4.1 - Definição do p-value associado ao F calculado

# %%
from scipy.stats import f

1 - f.cdf(F, df_modelo, df_residuos)
# Out:
# 0.0003144488029083181

# %% [markdown]
# ### 1.2.5 - Distribuição t de Student

# %%
df = 40

t_values = np.random.standard_t(df, 100000)

plt.hist(t_values, bins=100, edgecolor='k')
# Out:
# (array([2.000e+00, 1.000e+00, 0.000e+00, 3.000e+00, 2.000e+00, 1.000e+00,
#         3.000e+00, 6.000e+00, 7.000e+00, 5.000e+00, 6.000e+00, 5.000e+00,
#         1.300e+01, 2.300e+01, 2.400e+01, 3.500e+01, 4.100e+01, 6.200e+01,
#         4.900e+01, 8.600e+01, 1.130e+02, 1.300e+02, 1.400e+02, 1.690e+02,
#         2.310e+02, 2.870e+02, 3.290e+02, 3.940e+02, 4.750e+02, 5.810e+02,
#         6.300e+02, 8.120e+02, 9.140e+02, 1.100e+03, 1.185e+03, 1.401e+03,
#         1.599e+03, 1.720e+03, 1.963e+03, 2.221e+03, 2.453e+03, 2.553e+03,
#         2.754e+03, 3.054e+03, 3.100e+03, 3.312e+03, 3.465e+03, 3.437e+03,
#         3.555e+03, 3.602e+03, 3.717e+03, 3.667e+03, 3.511e+03, 3.579e+03,
#         3.425e+03, 3.393e+03, 3.176e+03, 2.920e+03, 2.779e+03, 2.574e+03,
#         2.392e+03, 2.201e+03, 1.985e+03, 1.696e+03, 1.546e+03, 1.376e+03,
#         1.253e+03, 1.090e+03, 9.430e+02, 8.030e+02, 6.690e+02, 6.020e+02,
#         5.010e+02, 3.950e+02, 3.570e+02, 2.620e+02, 2.200e+02, 1.790e+02,
#         1.560e+02, 1.190e+02, 1.010e+02, 6.700e+01, 6.600e+01, 4.900e+01,
#         3.900e+01, 2.400e+01, 2.600e+01, 2.400e+01, 1.500e+01, 1.100e+01,
#         1.100e+01, 8.000e+00, 5.000e+00, 5.000e+00, 4.000e+00, 3.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([-4.70026728, -4.60709216, -4.51391705, -4.42074193, -4.32756681,
#         -4.23439169, -4.14121658, -4.04804146, -3.95486634, -3.86169122,
#         -3.76851611, -3.67534099, -3.58216587, -3.48899075, -3.39581564,
#         -3.30264052, -3.2094654 , -3.11629028, -3.02311517, -2.92994005,
#         -2.83676493, -2.74358981, -2.65041469, -2.55723958, -2.46406446,
#         -2.37088934, -2.27771422, -2.18453911, -2.09136399, -1.99818887,
#         -1.90501375, -1.81183864, -1.71866352, -1.6254884 , -1.53231328,
#         -1.43913817, -1.34596305, -1.25278793, -1.15961281, -1.0664377 ,
#         -0.97326258, -0.88008746, -0.78691234, -0.69373722, -0.60056211,
#         -0.50738699, -0.41421187, -0.32103675, -0.22786164, -0.13468652,
#         -0.0415114 ,  0.05166372,  0.14483883,  0.23801395,  0.33118907,
#          0.42436419,  0.5175393 ,  0.61071442,  0.70388954,  0.79706466,
#          0.89023977,  0.98341489,  1.07659001,  1.16976513,  1.26294025,
#          1.35611536,  1.44929048,  1.5424656 ,  1.63564072,  1.72881583,
#          1.82199095,  1.91516607,  2.00834119,  2.1015163 ,  2.19469142,
#          2.28786654,  2.38104166,  2.47421677,  2.56739189,  2.66056701,
#          2.75374213,  2.84691724,  2.94009236,  3.03326748,  3.1264426 ,
#          3.21961772,  3.31279283,  3.40596795,  3.49914307,  3.59231819,
#          3.6854933 ,  3.77866842,  3.87184354,  3.96501866,  4.05819377,
#          4.15136889,  4.24454401,  4.33771913,  4.43089424,  4.52406936,
#          4.61724448]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# #### 1.2.5.1 - Cálculo do p-value da estatística t

# %% [markdown]
# O p-value associado à estatística $t$ é igual ao valor do p-value para a estatística $F$ na regressão linear simples.

# %%
import numpy as np
from scipy.stats import t

t_stat=np.sqrt(F)
t_stat
# Out:
# 6.025204311655633

# %%
t.sf(t_stat, df_residuos)*2
# Out:
# 0.00031444880290832364

# %% [markdown]
# ### 1.2.6 - Gráficos de regressão para diferentes níveis de confiança

# %%
# Gráfico com intervalo de confiança de 90%

plt.figure(figsize=(15,10))
sns.regplot(data=df_tempodist, x='distancia', y='tempo', marker='o', ci=90,
            scatter_kws={"color":'navy', 'alpha':0.7, 's':220},
            line_kws={"color":'grey', 'linewidth': 5})
plt.title('IC: 90%', fontsize=30)
plt.xlabel('Distância', fontsize=24)
plt.ylabel('Tempo', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0, 35)
plt.ylim(0, 60)
plt.legend(['Valores Reais', 'Fitted Values', '90% IC'],
           fontsize=24, loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# In[1.12]: Gráfico com intervalo de confiança de 95%

plt.figure(figsize=(15,10))
sns.regplot(data=df_tempodist, x='distancia', y='tempo', marker='o', ci=95,
            scatter_kws={"color":'navy', 'alpha':0.7, 's':220},
            line_kws={"color":'grey', 'linewidth': 5})
plt.title('IC: 95%', fontsize=30)
plt.xlabel('Distância', fontsize=24)
plt.ylabel('Tempo', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0, 35)
plt.ylim(0, 60)
plt.legend(['Valores Reais', 'Fitted Values', '95% IC'],
           fontsize=24, loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# In[1.13]: Gráfico com intervalo de confiança de 99%

plt.figure(figsize=(15,10))
sns.regplot(data=df_tempodist, x='distancia', y='tempo', marker='o', ci=99,
            scatter_kws={"color":'navy', 'alpha':0.7, 's':220},
            line_kws={"color":'grey', 'linewidth': 5})
plt.title('IC: 99%', fontsize=30)
plt.xlabel('Distância', fontsize=24)
plt.ylabel('Tempo', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0, 35)
plt.ylim(0, 60)
plt.legend(['Valores Reais', 'Fitted Values', '99% IC'],
           fontsize=24, loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# In[1.14]: Gráfico com intervalo de confiança de 99,99999%

plt.figure(figsize=(15,10))
sns.regplot(data=df_tempodist, x='distancia', y='tempo', marker='o', ci=99.99999,
            scatter_kws={"color":'navy', 'alpha':0.7, 's':220},
            line_kws={"color":'grey', 'linewidth': 5})
plt.title('IC: 99,99999%', fontsize=30)
plt.xlabel('Distância', fontsize=24)
plt.ylabel('Tempo', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0, 35)
plt.ylim(0, 60)
plt.legend(['Valores Reais', 'Fitted Values', '99,99999% IC'],
           fontsize=24, loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.2.7 - Cálculo dos intervalos de confiança

# %% [markdown]
# Para analisar se os valores são estatísticamente significativos, basta verificar se os parâmetros estimados $\alpha$ e $\beta$ estão em intervalos que contém o $0$.

# %%
modelo.summary()
# Out:
# C:\Users\Lucas Rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning:
#
# kurtosistest only valid for n>=20 ... continuing anyway, n=10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  tempo   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     36.30
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):           0.000314
# Time:                        20:46:06   Log-Likelihood:                -32.123
# No. Observations:                  10   AIC:                             68.25
# Df Residuals:                       8   BIC:                             68.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.8784      4.532      1.297      0.231      -4.573      16.330
# distancia      1.4189      0.235      6.025      0.000       0.876       1.962
# ==============================================================================
# Omnibus:                        1.016   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.602   Jarque-Bera (JB):                0.694
# Skew:                          -0.262   Prob(JB):                        0.707
# Kurtosis:                       1.820   Cond. No.                         41.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# In[1.15]: Calculando os intervalos de confiança

# Nível de significância de 10% / Nível de confiança de 90%
modelo.conf_int(alpha=0.1)
# Out:
#                   0          1
# Intercept -2.549702  14.306459
# distancia  0.981001   1.856837

# %%
# Nível de significância de 5% / Nível de confiança de 95%
modelo.conf_int(alpha=0.05)
# Out:
#                   0          1
# Intercept -4.573188  16.329944
# distancia  0.875861   1.961977

# %%
# Nível de significância de 1% / Nível de confiança de 99%
modelo.conf_int(alpha=0.01)
# Out:
#                   0          1
# Intercept -9.329336  21.086093
# distancia  0.628735   2.209103

# %%
# Nível de significância de 0,00001% / Nível de confiança de 99,99999%
modelo.conf_int(alpha=0.0000001)
# Out:
#                    0          1
# Intercept -74.960201  86.716957
# distancia  -2.781409   5.619247

# %% [markdown]
# Nessa análise, podemos ver que para o intervalo de confiança de 99,99999% o parâmetro $\beta$ não é estatísticamente significativo, pois o intervalo de confiança contém o valor 0.

# %% [markdown]
# ### 1.2.8 - Fazendo predições em modelos OLS

# %%
# In[1.16]: Fazendo predições em modelos OLS
# Ex.: Qual seria o tempo gasto, em média, para percorrer a distância de 25km?

# Cálculo manual
5.8784 + 1.4189*(25)

# Cálculo utilizando os próprios parâmetros estimados do modelo
modelo.params.iloc[0] + modelo.params.iloc[1]*(25)

# Maneira direta utilizando a função 'DataFrame' do pacote 'pandas' dentro
#da função 'predict'
modelo.predict(pd.DataFrame({'distancia':[25]}))
# Out:
# 0    41.351351
# dtype: float64

# %% [markdown]
# ### 1.2.9 - Cuidados na análise

# %% [markdown]
# Caso o $\alpha$ não seja estatísticamente significativo, não significa que ele seja igual a 0. Não iguale o alpha a zero! **Esse é um procedimento errado!!!**. O $\alpha$ sempre fica. Vale ressaltar que o teste $F$ não tem capacidade de inferir se o parâmetro $\alpha$ é estatísticamente significativo. Retirar o $\alpha$ gera um viés na análise.
#
# **Dica**: Não se importe com a significância estatística do $\alpha$, pois ele é um problema de tamanho de amostra.

# %% [markdown]
# # 2 - Supervised Machine Learning: Regressão Linear Múltipla

# %% [markdown]
# Base de dados sobre a percepção das pessoas em relação aos indicadores de corrupção.
#
# cpi = corruption perception index\
# idade = idade média dos bilionários\
# horas = horas trabalhadas pela população por semana
#
# Vamos estimar um modelo onde
#
# \begin{equation}
# \hat{\text{cpi}}_i = \alpha + \beta_1.\text{idade}_i + \beta_2.\text{horas}_i
# \end{equation}

# %% [markdown]
# ## 2.1 - Carregando a base de dados

# %%
df_paises = pd.read_csv('paises.csv', delimiter=',', encoding="utf-8")
df_paises[0:5]
# Out:
#         pais  cpi  idade  horas
# 0  Argentina  3.9     72   35.0
# 1  Australia  8.7     64   32.0
# 2    Austria  7.9     72   32.0
# 3    Belgium  7.1     67   30.1
# 4     Brazil  4.0     59   35.0

# %%
#Características das variáveis do dataset
df_paises.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pais    50 non-null     object
#  1   cpi     50 non-null     float64
#  2   idade   50 non-null     int64
#  3   horas   50 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.7+ KB

# %%
#Estatísticas univariadas
df_paises.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pais    50 non-null     object
#  1   cpi     50 non-null     float64
#  2   idade   50 non-null     int64
#  3   horas   50 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.7+ KB
#              cpi      idade      horas
# count  50.000000  50.000000  50.000000
# mean    4.894000  60.480000  32.660000
# std     2.678974  10.022913   2.431091
# min     0.800000  34.000000  26.800000
# 25%     2.575000  58.000000  31.400000
# 50%     3.950000  62.000000  32.600000
# 75%     7.475000  66.750000  34.400000
# max     9.300000  79.000000  38.100000

# %% [markdown]
# ## 2.2 - Scatter plot

# %%
# In[2.1]: Gráfico 3D com scatter gerado em HTML e aberto no browser
#(figura 'EXEMPLO2_scatter3D.html' salva na pasta do curso)

trace = go.Scatter3d(
    x=df_paises['horas'], 
    y=df_paises['idade'], 
    z=df_paises['cpi'], 
    mode='markers',
    marker={
        'size': 10,
        'color': 'darkorchid',
        'opacity': 0.7,
    },
)

layout = go.Layout(
    margin={'l': 0, 'r': 0, 'b': 0, 't': 0},
    width=800,
    height=800,
    plot_bgcolor='white',
    scene=dict(
        xaxis=dict(
            gridcolor='rgb(200, 200, 200)',
            backgroundcolor='whitesmoke'
        ),
        yaxis=dict(
            gridcolor='rgb(200, 200, 200)',
            backgroundcolor='whitesmoke'
        ),
        zaxis=dict(
            gridcolor='rgb(200, 200, 200)',
            backgroundcolor='whitesmoke'
        )
    )
)

data = [trace]

plot_figure = go.Figure(data=data, layout=layout)
plot_figure.update_layout(scene=dict(
    xaxis_title='horas',
    yaxis_title='idade',
    zaxis_title='cpi'
))

plot_figure.write_html('EXEMPLO2_scatter3D.html')

# Abre o arquivo HTML no browser
import webbrowser
webbrowser.open('EXEMPLO2_scatter3D.html')
# Out:
# True

# %% [markdown]
# ## 2.3 - Matriz de correlações

# %%
# In[2.2]: Matriz de correlações

correlation_matrix = df_paises.iloc[:,1:4].corr()
correlation_matrix

# Mapa de calor com as correlações entre todas as variáveis quantitativas
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".4f",
                      cmap=plt.cm.magma,
                      annot_kws={'size': 25}, vmin=-1, vmax=1)
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=17)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=17)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=17)
plt.show()

# Paletas de cores ('_r' reverte a sequência de cores):
# viridis
# inferno
# magma
# cividis
# coolwarm
# Blues
# Greens
# Reds

# %%
# In[2.4]: Matriz de correlações mais elaborada, com uso da função 'rcorr' do
#pacote 'pingouin'

import pingouin as pg

correlation_matrix2 = pg.rcorr(df_paises, method='pearson',
                               upper='pval', decimals=6,
                               pval_stars={0.01: '***',
                                           0.05: '**',
                                           0.10: '*'})
correlation_matrix2
# Out:
# C:\Users\Lucas Rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\pingouin\correlation.py:1116: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#              cpi      idade horas
# cpi            -        ***   ***
# idade   0.442838          -
# horas  -0.435724  -0.191748     -

# %% [markdown]
# ## 2.4 - Inter relação entre as variáveis através do grafo

# %%
# !pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.7 MB 1.8 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.7 MB 2.3 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.7 MB 3.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.7 MB 3.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.7 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.7 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.3
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# In[2.3]: Diagrama interessante (grafo) que mostra a inter-relação entre as
#variáveis e a magnitude das correlações entre elas

import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Criação de um grafo direcionado
G = nx.DiGraph()

# Adição das variáveis como nós do grafo
for variable in correlation_matrix.columns:
    G.add_node(variable)

# Adição das arestas com espessuras proporcionais às correlações
for i, variable1 in enumerate(correlation_matrix.columns):
    for j, variable2 in enumerate(correlation_matrix.columns):
        if i != j:
            correlation = correlation_matrix.iloc[i, j]
            if abs(correlation) > 0:
                G.add_edge(variable1, variable2, weight=correlation)

# Obtenção da lista de correlações das arestas
correlations = [d["weight"] for _, _, d in G.edges(data=True)]

# Definição da dimensão dos nós
node_size = 2700

# Definição da cor dos nós
node_color = 'black'

# Definição da escala de cores das retas (correspondência com as correlações)
cmap = plt.colormaps.get_cmap('coolwarm_r')

# Criação de uma lista de espessuras das arestas proporcional às correlações
edge_widths = [abs(d["weight"]) * 25 for _, _, d in G.edges(data=True)]

# Criação do layout do grafo com maior distância entre os nós
pos = nx.spring_layout(G, k=0.75)  # k para controlar a distância entre os nós

# Desenho dos nós e das arestas com base nas correlações e espessuras
nx.draw_networkx_nodes(G, pos, node_size=node_size, node_color=node_color)
nx.draw_networkx_edges(G, pos, width=edge_widths, edge_color=correlations,
                       edge_cmap=cmap, alpha=0.7)

# Adição dos rótulos dos nós
labels = {node: node for node in G.nodes}
nx.draw_networkx_labels(G, pos, labels, font_size=10, font_color='white')

# Ajuste dos limites dos eixos
ax = plt.gca()
ax.margins(0.1)
plt.axis("off")

# Criação da legenda com a escala de cores definida
smp = cm.ScalarMappable(cmap=cmap)
smp.set_array([min(correlations), max(correlations)])
cbar = plt.colorbar(smp, ax=ax, label='Correlação')

# Exibição do gráfico
plt.show()

# %% [markdown]
# ## 2.5 - Gráfico da distrbuição das variáveis

# %%
# In[2.5]: Gráfico com distribuições das variáveis, scatters, valores das
#correlações e respectivas significâncias estatísticas

def corrfunc(x, y, **kws):
    (r, p) = pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.3f}".format(r),
                xy=(.30, .9), xycoords=ax.transAxes, fontsize=14)
    ax.annotate("p = {:.3f}".format(p),
                xy=(.30, .8), xycoords=ax.transAxes, fontsize=14)

# Configuração do gráfico
sns.set(style="whitegrid", palette="viridis")

plt.figure(figsize=(20,10))
graph = sns.pairplot(df_paises, diag_kind="kde", plot_kws={"color": "darkorchid"},
                     height=2.5, aspect=1.7)
graph.map(corrfunc)
for ax in graph.axes.flat:
    ax.set_xlabel(ax.get_xlabel(), fontsize=14)
    ax.set_ylabel(ax.get_ylabel(), fontsize=14)
plt.show()

# %% [markdown]
# ## 2.6 - Estimação da Regressão Linear Múltipla

# %%
# In[2.6]: Estimação de um modelo de regressão múltipla com as variáveis do
#dataframe 'df_paises'

# Estimando o modelo de regressão múltipla por OLS
modelo_paises = sm.OLS.from_formula("cpi ~ idade + horas", df_paises).fit()

# %%
# Parâmetros do 'modelo_paises'
modelo_paises.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cpi   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     11.26
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):           0.000101
# Time:                        21:29:51   Log-Likelihood:                -109.93
# No. Observations:                  50   AIC:                             225.9
# Df Residuals:                      47   BIC:                             231.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.9719      5.165      2.318      0.025       1.581      22.363
# idade          0.0997      0.033      3.052      0.004       0.034       0.165
# horas         -0.4013      0.135     -2.980      0.005      -0.672      -0.130
# ==============================================================================
# Omnibus:                        3.389   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.184   Jarque-Bera (JB):                1.762
# Skew:                           0.131   Prob(JB):                        0.414
# Kurtosis:                       2.119   Cond. No.                     1.13e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Lembrando que o objetivo do modelo é encontrar um ajuste do tipo:
#
# \begin{equation}
# \hat{\text{cpi}}_i = \alpha + \beta_1.\text{idade}_i + \beta_2.\text{horas}_i
# \end{equation}
#
# Portanto:
#
# \begin{equation}
# \hat{\text{cpi}}_i = 11,972 + 0,997.\text{idade}_i + -0,401.\text{horas}_i
# \end{equation}

# %%
# Exemplo de cálculo

alpha = 11.972
beta_1 = 0.0997
beta_2 = -0.401

idade = 40
horas = 30

cpi = alpha + beta_1*idade + beta_2*horas
cpi
# Out:
# 3.929999999999998

# %%
0.4357**2
# Out:
# 0.18983448999999997

# %%
# Cálculo do R² ajustado (slide 31 da apostila)
r2_ajust = 1-((len(df_paises.index)-1)/(len(df_paises.index)-\
                                          modelo_paises.params.count()))*\
    (1-modelo_paises.rsquared)
r2_ajust # modo direto: modelo_paises.rsquared_adj
# Out:
# 0.295099700531963

# %%
# In[2.7]: Salvando os fitted values na base de dados

df_paises['cpifit'] = modelo_paises.fittedvalues
df_paises
# Out:
#               pais  cpi  idade  horas    cpifit
# 0        Argentina  3.9     72   35.0  5.103394
# 1        Australia  8.7     64   32.0  5.509820
# 2          Austria  7.9     72   32.0  6.307405
# 3          Belgium  7.1     67   30.1  6.571454
# 4           Brazil  4.0     59   35.0  3.807319
# 5           Canada  8.9     61   33.4  4.648854
# 6            Chile  6.2     70   34.0  5.305335
# 7            China  2.5     49   34.0  3.211674
# 8         Colombia  4.0     79   33.0  6.603955
# 9           Cyprus  6.3     58   32.0  4.911631
# 10       Czech_Rep  4.6     42   38.1  0.868307
# 11         Denmark  9.3     76   30.0  7.508870
# 12           Egypt  2.1     59   32.0  5.011329
# 13          France  6.8     70   30.0  6.910682
# 14         Germany  7.9     66   27.5  7.515231
# 15          Greece  3.5     60   30.0  5.913701
# 16         Iceland  8.5     53   31.0  4.814477
# 17           India  2.3     56   29.8  5.595175
# 18       Indonesia  1.8     63   33.5  4.808116
# 19            Iraq  0.8     42   32.0  3.316461
# 20         Ireland  8.0     63   31.3  5.691057
# 21           Italy  3.9     66   35.1  4.465072
# 22          Jordan  2.0     58   32.0  4.911631
# 23      Kazakhstan  1.9     44   33.9  2.753318
# 24          Kuwait  2.8     62   32.4  5.149889
# 25         Lebanon  1.5     39   31.7  3.137768
# 26        Malaysia  3.4     73   32.8  6.086033
# 27     Netherlands  8.8     61   26.8  7.297676
# 28     New_Zealand  9.3     65   31.0  6.010854
# 29          Norway  8.6     64   27.1  7.476370
# 30            Oman  3.3     58   33.2  4.430027
# 31     Philippines  1.4     75   34.7  5.522890
# 32          Poland  5.3     50   38.0  1.706026
# 33        Portugal  6.0     69   33.2  5.526706
# 34         Romania  3.7     67   34.5  4.805572
# 35          Russia  2.1     46   34.9  2.551377
# 36    Saudi_Arabia  3.7     58   33.8  4.189225
# 37          Serbia  3.5     61   34.5  4.207383
# 38    South_Africa  2.8     64   37.8  3.182067
# 39           Spain  6.1     62   31.8  5.390691
# 40          Sweden  9.2     70   30.0  6.910682
# 41     Switzerland  8.7     65   32.0  5.609518
# 42           Syria  1.0     34   32.0  2.518876
# 43          Taiwan  3.8     63   34.1  4.567314
# 44        Thailand  2.5     68   31.2  6.229681
# 45          Turkey  4.4     61   34.5  4.207383
# 46         Ukraine  2.4     44   32.8  3.194788
# 47  United_Kingdom  7.6     60   32.1  5.070893
# 48   United_States  7.1     65   34.5  4.606176
# 49       Venezuela  2.8     51   34.9  3.049868

# %% [markdown]
# ---
# ## Comparação entre modelos
#
# Quando houver o intuito de se compararem os resultados das estimações de dois modelos com quantidades distintas de parâmetros e/ou obtidos a partir de amostras com tamanhos diferentes, faz-se necessário o uso do R² ajustado.
#
# \begin{equation}
# R^2_\text{ajust} = 1 - \frac{n-1}{n-1-k}.(1-R^2)
# \end{equation}
#
# Onde:
#
# $n=$ tamanho da amostra\
# $k=$ quantidade de variáveis $X$ explicativas
#
# ---

# %%
# In[2.8]: Gráfico 3D com scatter e fitted values (superfície espacial)
#resultantes do 'modelo_paises', gerado em HTML e aberto no browser
#(figura 'EXEMPLO2_scatter3D_fitted.html' salva na pasta do curso)

trace = go.Scatter3d(
    x=df_paises['horas'], 
    y=df_paises['idade'], 
    z=df_paises['cpi'], 
    mode='markers',
    marker={
        'size': 10,
        'color': 'darkorchid',
        'opacity': 0.7,
    },
)

layout = go.Layout(
    margin={'l': 0, 'r': 0, 'b': 0, 't': 0},
    width=800,
    height=800,
    plot_bgcolor='white',
    scene=dict(
        xaxis=dict(
            gridcolor='rgb(200, 200, 200)',
            backgroundcolor='whitesmoke'
        ),
        yaxis=dict(
            gridcolor='rgb(200, 200, 200)',
            backgroundcolor='whitesmoke'
        ),
        zaxis=dict(
            gridcolor='rgb(200, 200, 200)',
            backgroundcolor='whitesmoke'
        )
    )
)

data = [trace]

plot_figure = go.Figure(data=data, layout=layout)
plot_figure.add_trace(go.Mesh3d(
                    x=df_paises['horas'], 
                    y=df_paises['idade'], 
                    z=df_paises['cpifit'], 
                    opacity=0.5,
                    color='orange'
                  ))
plot_figure.update_layout(scene = dict(
                        xaxis_title='horas',
                        yaxis_title='idade',
                        zaxis_title='cpi'))

plot_figure.write_html('EXEMPLO2_scatter3D_fitted.html')

# Abre o arquivo HTML no browser
import webbrowser
webbrowser.open('EXEMPLO2_scatter3D_fitted.html')
# Out:
# True

# %% [markdown]
# # 3 - Supervised Machine Learning: Regressão linear múltipla com variável qualitativa

# %% [markdown]
# ## 3.1 - Análise corrupcao.csv

# %% [markdown]
# O objetivo é construir um modelo onde avaliamos o cpi (corruption perception index) em função da região. Como a região é uma variável qualitativa, então devemos utilizar uma técnica chamada de *dummyzação*.

# %% [markdown]
# ### 3.1.1 - Carregando a base da dados

# %%
df_corrupcao = pd.read_csv('corrupcao.csv',delimiter=',',encoding='utf-8')
df_corrupcao[0:5]
# Out:
#         pais  cpi          regiao
# 0  Argentina  3.9  America_do_sul
# 1  Australia  8.7         Oceania
# 2    Austria  7.9          Europa
# 3    Belgium  7.1          Europa
# 4     Brazil  4.0  America_do_sul

# %%
# Características das variáveis do dataset
df_corrupcao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pais    50 non-null     object
#  1   cpi     50 non-null     float64
#  2   regiao  50 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Estatísticas univariadas
df_corrupcao.describe()
# Out:
#              cpi
# count  50.000000
# mean    4.894000
# std     2.678974
# min     0.800000
# 25%     2.575000
# 50%     3.950000
# 75%     7.475000
# max     9.300000

# %%
# Estatísticas univariadas por região
df_corrupcao.groupby('regiao').describe()
# Out:
#                  cpi
#                count      mean       std  min    25%   50%    75%  max
# regiao
# America_do_sul   5.0  4.180000  1.237740  2.8  3.900  4.00  4.000  6.2
# Asia            17.0  2.329412  0.898446  0.8  1.800  2.30  2.800  3.8
# EUA_e_Canada     2.0  8.000000  1.272792  7.1  7.550  8.00  8.450  8.9
# Europa          24.0  6.258333  2.272504  2.1  4.275  6.55  8.125  9.3
# Oceania          2.0  9.000000  0.424264  8.7  8.850  9.00  9.150  9.3

# %%
# In[3.1]: Tabela de frequências da variável 'regiao'

# Função 'value_counts' do pacote 'pandas' sem e com o argumento 'normalize'
#para gerar, respectivamente, as contagens e os percentuais
contagem = df_corrupcao['regiao'].value_counts(dropna=False)
percent = df_corrupcao['regiao'].value_counts(dropna=False, normalize=True)
pd.concat([contagem, percent], axis=1, keys=['contagem', '%'], sort=False)
# Out:
#                 contagem     %
# regiao
# Europa                24  0.48
# Asia                  17  0.34
# America_do_sul         5  0.10
# Oceania                2  0.04
# EUA_e_Canada           2  0.04

# %%
# In[3.2]: Conversão dos dados de 'regiao' para dados numéricos, a fim de
#se mostrar a estimação de modelo com o problema da ponderação arbitrária

label_encoder = LabelEncoder()
df_corrupcao['regiao_numerico'] = label_encoder.fit_transform(df_corrupcao['regiao'])
df_corrupcao['regiao_numerico'] = df_corrupcao['regiao_numerico'] + 1
df_corrupcao.head(10)

# A nova variável 'regiao_numerico' é quantitativa (ERRO!), fato que
#caracteriza a ponderação arbitrária!
df_corrupcao['regiao_numerico'].info()
df_corrupcao.describe()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50 entries, 0 to 49
# Series name: regiao_numerico
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     int32
# dtypes: int32(1)
# memory usage: 332.0 bytes
#              cpi  regiao_numerico
# count  50.000000        50.000000
# mean    4.894000         3.020000
# std     2.678974         1.186489
# min     0.800000         1.000000
# 25%     2.575000         2.000000
# 50%     3.950000         4.000000
# 75%     7.475000         4.000000
# max     9.300000         5.000000

# %%
from numpy.random import randint as ri

ri(1000, 9999, 4)
# Out:
# array([6425, 2880, 1947, 8518])
